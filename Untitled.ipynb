# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
from tabulate import tabulate
import pandas as pd
import os
import pprint

# %%
executable_path = {'executable_path': 'chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
#'https://www.ewg.org/tapwater/state.php?stab=TX'
#set url to variable 'url'
url = "https://www.ewg.org/tapwater/state.php?stab=TX"

# %%
# create a new Chrome session
driver = webdriver.Chrome()
driver.implicitly_wait(30)
driver.get(url)

# %%
#Selenium hands of the source of the specific job page to Beautiful Soup
soup_level2=BeautifulSoup(driver.page_source, 'lxml')

# %%
table = soup_level2.find_all('tr')
water_df=pd.DataFrame(table)
water_df[0][0]
# Out:
# <tr><th>Utility</th><th>Location</th><th>People<br/>Served</th></tr>

# %%
listofdata=[]
for i in soup_level2.find_all('td'):
    listofdata.append(i.text)   
data_df=pd.DataFrame(listofdata,columns=['data'])
# Out:
#                                 data
# 0                          Acton MUD
# 1                       Granbury, TX
# 2                             17,855
# 3                           Agua SUD
# 4                        Mission, TX
# 5                             45,498
# 6    Amarillo Municipal Water System
# 7                       Amarillo, TX
# 8                            196,429
# 9      Aqua Water Supply Corporation
# 10                       Bastrop, TX
# 11                            56,601
# 12                Atascosa Rural WSC
# 13                      Atascosa, TX
# 14                            10,482
# 15          Benbrook Water Authority
# 16                      Benbrook, TX
# 17                            21,530
# 18                   Benton City WSC
# 19                         Lytle, TX
# 20                            17,292
# 21                      Bethesda WSC
# 22                      Burleson, TX
# 23                            29,763
# ...

# %%
# water_df[water_df[0].str.contains("taminant")]

# %%
data_df[data_df['data'].str.contains("Total")==True]
# Out:
#                               data
# 330  Total trihalomethanes (TTHMs)
# 682  Total trihalomethanes (TTHMs)

# %%
new_list=[]
i=330
for i in range(330,681):
    new_data=data_df[i]
    new_list.append[new_data]
    i+=1
print(new_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 330
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-a9e6627bce22> in <module>
#       2 i=330
#       3 for i in range(330,681):
# ...
